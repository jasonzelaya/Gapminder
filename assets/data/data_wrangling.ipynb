# %%
# Import dependencies
import os
import pandas as pd
import numpy as np
import country_converter as coco
cc = coco.CountryConverter()

# %%
# View files in 'raw_data'
os.listdir("raw_data")
# Out:
# ['ddf--entities--geo--world_4region.csv',
#  'income_per_person_gdppercapita_ppp_inflation_adjusted.csv',
#  'life_expectancy_years.csv',
#  'population_total.csv']

# %%
# Read data into pd data frames
# Change encoding from ANSI to UTF-8
income = pd.read_csv("raw_data/income_per_person_gdppercapita_ppp_inflation_adjusted.csv", encoding="utf-8")
lex = pd.read_csv("raw_data/life_expectancy_years.csv", encoding="utf-8")
pop = pd.read_csv("raw_data/population_total.csv", encoding="utf-8")
regions4 = pd.read_csv("raw_data/ddf--entities--geo--world_4region.csv", encoding="utf-8")

# %%
# Preview data frames
display(income.head())
display(lex.head())
display(pop.head())
display(regions4.head())
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan   603   603   603   603   603   603   603   603   603  ...
# 1      Albania   667   667   667   667   667   668   668   668   668  ...
# 2      Algeria   715   716   717   718   719   720   721   722   723  ...
# 3      Andorra  1200  1200  1200  1200  1210  1210  1210  1210  1220  ...
# 4       Angola   618   620   623   626   628   631   634   637   640  ...
#
#     2031   2032   2033   2034   2035   2036   2037   2038   2039   2040
# 0   2420   2470   2520   2580   2640   2700   2760   2820   2880   2940
# 1  18500  18900  19300  19700  20200  20600  21100  21500  22000  22500
# 2  15600  15900  16300  16700  17000  17400  17800  18200  18600  19000
# 3  73200  74800  76400  78100  79900  81600  83400  85300  87200  89100
# 4   6270   6410   6550   6700   6850   7000   7150   7310   7470   7640
#
# [5 rows x 242 columns]
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  ...
# 1      Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# 2      Algeria  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  ...
# 3      Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4       Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  ...
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0  55.7  56.2  56.7  57.2  57.7  57.8  57.9  58.0  58.4  58.7
# 1  75.9  76.3  76.7  77.0  77.2  77.4  77.6  77.7  77.9  78.0
# 2  76.3  76.5  76.7  76.8  77.0  77.1  77.3  77.4  77.6  77.9
# 3  82.7  82.7  82.6  82.6  82.6  82.6  82.5  82.5   NaN   NaN
# 4  59.3  60.1  60.9  61.7  62.5  63.3  64.0  64.7  64.9  65.2
#
# [5 rows x 220 columns]
#        country     1800     1801     1802     1803     1804     1805     1806  \
# 0  Afghanistan  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# 1      Albania   410000   412000   413000   414000   416000   417000   418000
# 2      Algeria  2500000  2510000  2520000  2530000  2540000  2550000  2560000
# 3      Andorra     2650     2650     2650     2650     2650     2650     2650
# 4       Angola  1570000  1570000  1570000  1570000  1570000  1570000  1570000
#
#       1807     1808  ...       2091       2092       2093       2094  \
# 0  3280000  3280000  ...   71900000   71800000   71600000   71500000
# 1   420000   421000  ...    1820000    1800000    1780000    1760000
# 2  2570000  2580000  ...   62800000   62800000   62800000   62800000
# 3     2650     2650  ...      64300      64200      64100      63900
# 4  1570000  1570000  ...  156000000  158000000  160000000  162000000
#
#         2095       2096       2097       2098       2099       2100
# 0   71300000   71200000   71000000   70800000   70600000   70400000
# 1    1740000    1720000    1710000    1690000    1670000    1660000
# 2   62800000   62800000   62700000   62700000   62600000   62600000
# 3      63800      63700      63500      63400      63300      63100
# 4  164000000  166000000  167000000  169000000  171000000  173000000
#
# [5 rows x 302 columns]
#   world_4region    color                                        description  \
# 0        africa  #00d5e9  The entire African continent, Madagascar and s...
# 1      americas  #7feb00  North, South & central America make up roughly...
# 2          asia  #ff5872  Asia as defined by Gapmidner, to make up rough...
# 3        europe  #ffe700  West & East Europe including all of Russia and...
#
#    is--world_4region  latitude  longitude          name  \
# 0               True -14.33333   28.50000        Africa
# 1               True   8.99360  -79.51973  The Americas
# 2               True  16.16667  107.83333          Asia
# 3               True  50.75000    4.50000        Europe
#
#                                            name_long name_short  rank  \
# 0  The African continent including Madagascar & o...     Africa     2
# 1                     North, South & Central America    America     3
# 2  Australia, Pacific Islands, South & South East...       Asia     1
# 3                  Central Asia, East & West Europe      Europe     4
#
#                                      shape_lores_svg
# 0  M322.7,114.7l-1-1.8l-6.5,2.3l-16-4.8l-2.3,1.7l...
# 1  M134.8,152l-11.4,1.8l-3.1-1.7l5.3-1.3l-0.7-1.1...
# 2  M322.9,118.9l22.8,42.5l13.5-5.9l16.8-19l-7.3-6...
# 3  M556.7,26.9l-35.5-7.3l-3.5,1.4l-49.9-5.2l-2.7,...

# %%
# View number of values in 'country' column for each data frame
display(income["country"].count())
display(lex["country"].count())
display(pop["country"].count())
# Out:
# 193
# 187
# 195

# %%
# Get only values present in all 'country' columns as a list
country_matches = list(set(income["country"]) & set(lex["country"]) & set(pop["country"]))

# Confirm number of 'country' column values does not exceed 187
print(len(country_matches))

# Preview list
print(country_matches[:5])
# Out:
# 187
# ['St. Vincent and the Grenadines', 'Kenya', 'Thailand', 'Turkey', 'Azerbaijan']

# %%
# Filter data frames by matching 'country' column values
income_matches = income[income['country'].isin(country_matches)]
lex_matches = lex[lex['country'].isin(country_matches)]
pop_matches = pop[pop['country'].isin(country_matches)]

# Confirm all data frames' 'country' columns have 187 rows
print(income_matches["country"].count())
print(lex_matches["country"].count())
print(pop_matches["country"].count())
# Out:
# 187
# 187
# 187

# %%
# Sort data frames by 'country' columns
income_sorted_matches = income_matches.sort_values(by=['country'])
lex_sorted_matches = lex_matches.sort_values(by=['country'])
pop_sorted_matches = pop_matches.sort_values(by=['country'])

# Preview dataframes
display(income_sorted_matches.head(3))
display(lex_sorted_matches.head(3))
display(pop_sorted_matches.head(3))
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan   603   603   603   603   603   603   603   603   603  ...
# 1      Albania   667   667   667   667   667   668   668   668   668  ...
# 2      Algeria   715   716   717   718   719   720   721   722   723  ...
#
#     2031   2032   2033   2034   2035   2036   2037   2038   2039   2040
# 0   2420   2470   2520   2580   2640   2700   2760   2820   2880   2940
# 1  18500  18900  19300  19700  20200  20600  21100  21500  22000  22500
# 2  15600  15900  16300  16700  17000  17400  17800  18200  18600  19000
#
# [3 rows x 242 columns]
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  ...
# 1      Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# 2      Algeria  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  ...
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0  55.7  56.2  56.7  57.2  57.7  57.8  57.9  58.0  58.4  58.7
# 1  75.9  76.3  76.7  77.0  77.2  77.4  77.6  77.7  77.9  78.0
# 2  76.3  76.5  76.7  76.8  77.0  77.1  77.3  77.4  77.6  77.9
#
# [3 rows x 220 columns]
#        country     1800     1801     1802     1803     1804     1805     1806  \
# 0  Afghanistan  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# 1      Albania   410000   412000   413000   414000   416000   417000   418000
# 2      Algeria  2500000  2510000  2520000  2530000  2540000  2550000  2560000
#
#       1807     1808  ...      2091      2092      2093      2094      2095  \
# 0  3280000  3280000  ...  71900000  71800000  71600000  71500000  71300000
# 1   420000   421000  ...   1820000   1800000   1780000   1760000   1740000
# 2  2570000  2580000  ...  62800000  62800000  62800000  62800000  62800000
#
#        2096      2097      2098      2099      2100
# 0  71200000  71000000  70800000  70600000  70400000
# 1   1720000   1710000   1690000   1670000   1660000
# 2  62800000  62700000  62700000  62600000  62600000
#
# [3 rows x 302 columns]

# %%
# Convert 'country' column values to continents and add the values as a new "Region" column in the data frames
income_sorted_matches["region"] = cc.convert(list(income_sorted_matches["country"]), to='continent')
lex_sorted_matches["region"] = cc.convert(list(lex_sorted_matches["country"]), to='continent')
pop_sorted_matches["region"] = cc.convert(list(pop_sorted_matches["country"]), to='continent')

# %%
# Preview each dataframe
display(income_sorted_matches.head(3))
display(lex_sorted_matches.head(3))
display(pop_sorted_matches.head(3))
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan   603   603   603   603   603   603   603   603   603  ...
# 1      Albania   667   667   667   667   667   668   668   668   668  ...
# 2      Algeria   715   716   717   718   719   720   721   722   723  ...
#
#     2032   2033   2034   2035   2036   2037   2038   2039   2040  region
# 0   2470   2520   2580   2640   2700   2760   2820   2880   2940    Asia
# 1  18900  19300  19700  20200  20600  21100  21500  22000  22500  Europe
# 2  15900  16300  16700  17000  17400  17800  18200  18600  19000  Africa
#
# [3 rows x 243 columns]
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  ...
# 1      Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# 2      Algeria  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  ...
#
#    2010  2011  2012  2013  2014  2015  2016  2017  2018  region
# 0  56.2  56.7  57.2  57.7  57.8  57.9  58.0  58.4  58.7    Asia
# 1  76.3  76.7  77.0  77.2  77.4  77.6  77.7  77.9  78.0  Europe
# 2  76.5  76.7  76.8  77.0  77.1  77.3  77.4  77.6  77.9  Africa
#
# [3 rows x 221 columns]
#        country     1800     1801     1802     1803     1804     1805     1806  \
# 0  Afghanistan  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# 1      Albania   410000   412000   413000   414000   416000   417000   418000
# 2      Algeria  2500000  2510000  2520000  2530000  2540000  2550000  2560000
#
#       1807     1808  ...      2092      2093      2094      2095      2096  \
# 0  3280000  3280000  ...  71800000  71600000  71500000  71300000  71200000
# 1   420000   421000  ...   1800000   1780000   1760000   1740000   1720000
# 2  2570000  2580000  ...  62800000  62800000  62800000  62800000  62800000
#
#        2097      2098      2099      2100  region
# 0  71000000  70800000  70600000  70400000    Asia
# 1   1710000   1690000   1670000   1660000  Europe
# 2  62700000  62700000  62600000  62600000  Africa
#
# [3 rows x 303 columns]

# %%
# Confirm all "Region" values converted successfully
print(income_sorted_matches["region"].unique())
print(lex_sorted_matches["region"].unique())
print(pop_sorted_matches["region"].unique())
# Out:
# ['Asia' 'Europe' 'Africa' 'America' 'Oceania']
# ['Asia' 'Europe' 'Africa' 'America' 'Oceania']
# ['Asia' 'Europe' 'Africa' 'America' 'Oceania']

# %%
# To determine what to do with "Oceania" since Gapminder is using a 4 region dataset, match Oceania's
# definition with Gapminder's
pd.set_option('display.max_colwidth', -1)
regions4[["world_4region", "name_long"]]
# Out:
#   world_4region                                                   name_long
# 0  africa        The African continent including Madagascar & other islands
# 1  americas      North, South & Central America
# 2  asia          Australia, Pacific Islands, South & South East Asia
# 3  europe        Central Asia, East & West Europe

# %%
# Wikipedia definitions for Australia, Pacific Islands, and South & South East Asia all describe their
# relationship with Oceania
# 'Oceania' values will be converted to 'Asia' values

# Number of 'Asia' rows before Oceania conversion
display(income_sorted_matches.groupby("region").size())
display(lex_sorted_matches.groupby("region").size())
display(pop_sorted_matches.groupby("region").size())
# Out:
# region
# Africa     54
# America    34
# Asia       48
# Europe     40
# Oceania    11
# dtype: int64
# region
# Africa     54
# America    34
# Asia       48
# Europe     40
# Oceania    11
# dtype: int64
# region
# Africa     54
# America    34
# Asia       48
# Europe     40
# Oceania    11
# dtype: int64

# %%
# Convert "Oceania" values to "Asia" values
income_sorted_matches["region"] = np.where((income_sorted_matches["region"] == "Oceania"), "Asia", income_sorted_matches["region"])
lex_sorted_matches["region"] = np.where((lex_sorted_matches["region"] == "Oceania"), "Asia", lex_sorted_matches["region"])
pop_sorted_matches["region"] = np.where((pop_sorted_matches["region"] == "Oceania"), "Asia", pop_sorted_matches["region"])

# %%
# Confirm changes successful
print(income_sorted_matches["region"].unique())
print(lex_sorted_matches["region"].unique())
print(pop_sorted_matches["region"].unique())
# Out:
# ['Asia' 'Europe' 'Africa' 'America']
# ['Asia' 'Europe' 'Africa' 'America']
# ['Asia' 'Europe' 'Africa' 'America']

# %%
# Number of 'Asia' rows after Oceania conversion
display(income_sorted_matches.groupby("region").size())
display(lex_sorted_matches.groupby("region").size())
display(pop_sorted_matches.groupby("region").size())
# Out:
# region
# Africa     54
# America    34
# Asia       59
# Europe     40
# dtype: int64
# region
# Africa     54
# America    34
# Asia       59
# Europe     40
# dtype: int64
# region
# Africa     54
# America    34
# Asia       59
# Europe     40
# dtype: int64

# %%
# Preview dataframes
display(income_sorted_matches.head(3))
display(lex_sorted_matches.head(3))
display(pop_sorted_matches.head(3))
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan  603   603   603   603   603   603   603   603   603   ...
# 1  Albania      667   667   667   667   667   668   668   668   668   ...
# 2  Algeria      715   716   717   718   719   720   721   722   723   ...
#
#     2032   2033   2034   2035   2036   2037   2038   2039   2040  region
# 0  2470   2520   2580   2640   2700   2760   2820   2880   2940   Asia
# 1  18900  19300  19700  20200  20600  21100  21500  22000  22500  Europe
# 2  15900  16300  16700  17000  17400  17800  18200  18600  19000  Africa
#
# [3 rows x 243 columns]
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  ...
# 1  Albania      35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# 2  Algeria      28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  ...
#
#    2010  2011  2012  2013  2014  2015  2016  2017  2018  region
# 0  56.2  56.7  57.2  57.7  57.8  57.9  58.0  58.4  58.7  Asia
# 1  76.3  76.7  77.0  77.2  77.4  77.6  77.7  77.9  78.0  Europe
# 2  76.5  76.7  76.8  77.0  77.1  77.3  77.4  77.6  77.9  Africa
#
# [3 rows x 221 columns]
#        country     1800     1801     1802     1803     1804     1805     1806  \
# 0  Afghanistan  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# 1  Albania      410000   412000   413000   414000   416000   417000   418000
# 2  Algeria      2500000  2510000  2520000  2530000  2540000  2550000  2560000
#
#       1807     1808  ...      2092      2093      2094      2095      2096  \
# 0  3280000  3280000  ...  71800000  71600000  71500000  71300000  71200000
# 1  420000   421000   ...  1800000   1780000   1760000   1740000   1720000
# 2  2570000  2580000  ...  62800000  62800000  62800000  62800000  62800000
#
#        2097      2098      2099      2100  region
# 0  71000000  70800000  70600000  70400000  Asia
# 1  1710000   1690000   1670000   1660000   Europe
# 2  62700000  62700000  62600000  62600000  Africa
#
# [3 rows x 303 columns]

# %%
# Save dataframes into CSV files
income_sorted_matches.to_csv("income_matches.csv", sep=",", index=False)
lex_sorted_matches.to_csv("lex_matches.csv", sep=",", index=False)
pop_sorted_matches.to_csv("pop_matches.csv", sep=",", index=False)

# %%
# Pivot datasets using Tableau

# %%
# View files in current directory
os.listdir()
# Out:
# ['data_transformation.ipynb',
#  'income_pivoted.csv',
#  'lex_pivoted.csv',
#  'pop_pivoted.csv',
#  'raw_data']

# %%
# Read data into pd data frames
income_pivot = pd.read_csv("income_pivoted.csv")
lex_pivot = pd.read_csv("lex_pivoted.csv")
pop_pivot = pd.read_csv("pop_pivoted.csv")

# %%
# Preview data frames
display(income_pivot.head())
display(lex_pivot.head())
display(pop_pivot.head())
# Out:
#    Number of Records  year  income      country  region
# 0  1                  1800  603     Afghanistan  Asia
# 1  1                  1800  667     Albania      Europe
# 2  1                  1800  715     Algeria      Africa
# 3  1                  1800  1200    Andorra      Europe
# 4  1                  1800  618     Angola       Africa
#    Number of Records  year  life_expectancy      country  region
# 0  1                  1800  28.2             Afghanistan  Asia
# 1  1                  1800  35.4             Albania      Europe
# 2  1                  1800  28.8             Algeria      Africa
# 3  1                  1800 NaN               Andorra      Europe
# 4  1                  1800  27.0             Angola       Africa
#    Number of Records  year  population      country  region
# 0  1                  1800  3280000     Afghanistan  Asia
# 1  1                  1800  410000      Albania      Europe
# 2  1                  1800  2500000     Algeria      Africa
# 3  1                  1800  2650        Andorra      Europe
# 4  1                  1800  1570000     Angola       Africa

# %%
# Remove unnecessary columns
income_drop = income_pivot.drop(columns=["Number of Records"])
lex_drop = lex_pivot.drop(columns=["Number of Records"])
pop_drop = pop_pivot.drop(columns=["Number of Records"])

# Confirm successful removal
print(income_drop.columns)
print(lex_drop.columns)
print(pop_drop.columns)
# Out:
# Index(['year', 'income', 'country', 'region'], dtype='object')
# Index(['year', 'life_expectancy', 'country', 'region'], dtype='object')
# Index(['year', 'population', 'country', 'region'], dtype='object')

# %%
# View min and max 'year' column values
print(income_drop["year"].min())
print(lex_drop["year"].min())
print(pop_drop["year"].min())

print(f"\n{income_drop['year'].max()}")
print(lex_drop["year"].max())
print(pop_drop["year"].max())
# Out:
# 1800
# 1800
# 1800
#
# 2040
# 2018
# 2100

# %%
# Filter all rows with 'year' values greater than '2018'
income_2018 = income_drop.loc[income_drop["year"] < 2019]
pop_2018 = pop_drop.loc[pop_drop["year"] < 2019]

# Confirm removal successful
print(income_2018["year"].max())
print(pop_2018["year"].max())
# Out:
# 2018
# 2018

# %%
# Keep data frame variables consistent
lex_2018 = lex_drop.copy()

# Preview data frame
lex_2018.head()
# Out:
#    year  life_expectancy      country  region
# 0  1800  28.2             Afghanistan  Asia
# 1  1800  35.4             Albania      Europe
# 2  1800  28.8             Algeria      Africa
# 3  1800 NaN               Andorra      Europe
# 4  1800  27.0             Angola       Africa

# %%
# Confirm row count still matches
display(income_2018.count())
display(lex_2018.count())
display(pop_2018.count())
# Out:
# year       40953
# income     40953
# country    40953
# region     40953
# dtype: int64
# year               40953
# life_expectancy    40437
# country            40953
# region             40953
# dtype: int64
# year          40953
# population    40953
# country       40953
# region        40953
# dtype: int64

# %%
# Check for row count discrepancies
display(income_2018.isnull().sum())
display(lex_2018.isnull().sum())
display(pop_2018.isnull().sum())
# Out:
# year       0
# income     0
# country    0
# region     0
# dtype: int64
# year               0
# life_expectancy    516
# country            0
# region             0
# dtype: int64
# year          0
# population    0
# country       0
# region        0
# dtype: int64

# %%
# Confirm row count matches if NaN values are taken into account
# NaNs will be removed once the datasets are merged
40437 + 516
# Out:
# 40953

# %%
# Merge all three data frames together
two_merged = pd.merge(income_2018, lex_2018)
all_merged = pd.merge(two_merged, pop_2018)

# Display dimensions
print(all_merged.shape)

# Preview merged data frame
all_merged.head()
# Out:
# (40953, 6)
#    year  income      country  region  life_expectancy  population
# 0  1800  603     Afghanistan  Asia    28.2             3280000
# 1  1800  667     Albania      Europe  35.4             410000
# 2  1800  715     Algeria      Africa  28.8             2500000
# 3  1800  1200    Andorra      Europe NaN               2650
# 4  1800  618     Angola       Africa  27.0             1570000

# %%
# Sort dataframe by 'year' column
sorted_merged = all_merged.sort_values(by=['year'])

# Confirm the first year is 1800 and the last year is 2018
display(sorted_merged.head(2))
sorted_merged.tail(2)
# Out:
#      year  income      country   region  life_expectancy  population
# 0    1800  603     Afghanistan  Asia     28.2             3280000
# 120  1800  973     Nicaragua    America  25.4             219000
#        year  income   country  region  life_expectancy  population
# 40823  2018  9420    Fiji      Asia    65.8             912000
# 40952  2018  1950    Zimbabwe  Africa  60.2             16900000

# %%
# Reorder columns
reordered_merged = sorted_merged[["year", "country", "region", "income", "life_expectancy", "population"]]

# Confirm reorder successful
reordered_merged.head(3)
# Out:
#      year      country   region  income  life_expectancy  population
# 0    1800  Afghanistan  Asia     603     28.2             3280000
# 120  1800  Nicaragua    America  973     25.4             219000
# 121  1800  Niger        Africa   446     30.8             1240000

# %%
# Remove rows with null values
clean_merged_data = reordered_merged.dropna()

clean_merged_data.reset_index(drop=True, inplace=True)

# Preview data frame
clean_merged_data.head()
# Out:
#    year      country   region  income  life_expectancy  population
# 0  1800  Afghanistan  Asia     603     28.2             3280000
# 1  1800  Nicaragua    America  973     25.4             219000
# 2  1800  Niger        Africa   446     30.8             1240000
# 3  1800  Nigeria      Africa   851     30.4             12100000
# 4  1800  North Korea  Asia     578     26.0             4340000

# %%
# Save data frame into CSV file
clean_merged_data.to_csv("all_data_cleaned.csv", sep=",", index=False)
